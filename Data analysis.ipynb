# %%
# %pylab inline
import numpy as np
import scipy as sp
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /home/qize/FDS_simulation/Copy_sever/mesh_sensitivity_study/1mm
# Out:
# /home/qize/FDS_simulation/Copy_sever/mesh_sensitivity_study/1mm

# %%
d = {'col1': ts1, 'col2': ts2}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fc76973ee17c> in <module>()
# ----> 1 d = {'col1': ts1, 'col2': ts2}
#
# NameError: name 'ts1' is not defined

# %%
Data =pd.read_csv('2D_CVC_V40_15SLPM_devc.csv', header=1)
Data.head(5)
# Out:
#        Time       FLOW_In  FLOW_Out     GAS02  GAS_Oxygen
# 0  0.000000  0.000000e+00  0.000000 -0.005005    0.230700
# 1  0.205548  2.240295e-09  0.000153 -0.009705    0.230700
# 2  0.407612  0.000000e+00  0.000619 -0.028278    0.230700
# 3  0.600872  0.000000e+00  0.001049 -0.005880    0.230677
# 4  0.802325  0.000000e+00  0.001462  0.153060    0.230656
#
# [5 rows x 5 columns]

# %%
plot(Data['Time'],Data['FLOW_In'], '-', color="blue")
plot(Data['Time'],Data['FLOW_Out'], '-', color="red")
xlabel('Time')
ylabel('FLOW')
title('Flow in and out')
show()

# %%
Dmass=Data['FLOW_In']-Data['FLOW_Out']
plot(Data['Time'],Dmass)
