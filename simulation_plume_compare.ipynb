# %%
# %pylab inline
import numpy as np
import scipy as sp
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import data from matlab file
import scipy.io as sio
mat1 = sio.loadmat('/home/qize/Documents/MATLAB/W2D/2700.mat')
WV=pd.DataFrame(mat1['VV'])


#plot contour
x = np.linspace(-0.4, 0.4, 41)
y = np.linspace(0, 1.6, 81)
X, Y = np.meshgrid(x, y)

fig = figure(figsize=(6,8))
contourf(X, Y, WV, 10, alpha=.75, cmap='jet')
colorbar()
CW=contour(X, Y, WV, 10, colors='black', linewidth=.5)
title('W-velocity',size=24)
clabel(CW, inline=1, fontsize=10)
# Out:
# <a list of 9 text.Text objects>

# %%
#plot W-velocity
x = np.linspace(-0.4, 0.4, 41)
fig = figure(figsize=(5,10))
suptitle('W-velocity with different height', size=16, position=(0.5,0.95))

for i in range(6):
    subplot(6,1,i+1)
    plot(x, WV.iloc[30-5*i], 'b-', linewidth=2)
    title('u / m/s',position=(0.6,0.9))
    xlim(-0.4,0.4)
    ylim(0,3.5)
    ax = gca()  # gca stands for 'get current axis'
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('data',0))
    ax.yaxis.set_ticks_position('left')
    ax.spines['left'].set_position(('data',0))
    ax.text(0.5, 0.3, 'H=%dmm' %(60-10*i),size=18, ha='left', va='center')
    grid(True)
