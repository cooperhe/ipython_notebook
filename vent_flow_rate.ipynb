# %% [markdown]
# # Why Horizontial Vent Flow? -- Motivation

# %% [markdown]
# **Vent flow calaulation is quite importment in fires, since it determines the ventilation condition of the fire in rooms. But as wrote by Howard W. Emmons in the SFPE handbook, "Unlike nonbuoyant flows through orifices or flow through vents in a vertical wall, very little quantitative work has been done on flow through vents in horizontal (floors or flat roofs) or slightly sloped (inclined roofs) surfaces". he also clarifid the present status of our knowledge only provided flow calculation formulas of unknown accuracy in lieu of nothing. Studys on horizontial vent flow under fire conditions are in great need but it is always not an easy job.**

# %% [markdown]
# ###Existing vent flow theory
#   <img src="sketch.png" alt="Drawing" style="width: 200px;"/>
#   Consider the flow through a hole in a horizontal surface. While the preseeure difference is significate, the velocity and flow rate can be determined from the pressure drop through a distance of holes using Bernoulli Equation.
#   <center>$$v=[\frac{2}{\rho}(\triangle \rho gh+\triangle p)]^{1/2}$$<center>
#
#   However, while it comes to a fire-induced ceiling vent flow, both pressure difference and density difference through the vent are small, leading the vent flow nearly zero. the interface between the lower (hot) and upper (cold) gases becomes flat and is unstable. The unidirectional flow is replaced by simultaneous up and down flows usually oscillating in time and location. In addition, ceiling or roof vents in fires are usually irregular in shape and have a length to “diameter” ratio of 0.13 or less. There are some studies of rooms with a ceiling hole with a fire under the vent. These supply interesting fire data but are not useful as horizontal vent studies, since the results do not include adequate orifice pressure and flow measurements.
#
#   The recent calculation of ceiling vent flow in fires was still based on Cooper's theory back to 1980s. Cooper considered that there will be a critical value of the pressure difference to distinguish between unidirectional flow regime and a mixed flow regime,
#   <center>$$\triangle P_{cri} = 0.2427(1+\frac{1}{2}ε) exp(1.1072ε) (4g \triangle ρ D)$$<center>
#
#   where $ε = -\triangle \rho / \overline \rho $ and is related to the Atwood number, $g$ is the acceleration due to gravity, $\triangle ρ$ is the density difference and $D$ is the equivalent diameter of the ceiling vent.
#
#   Correspondingly, the critical flow rate is
#   <center>$$\dot V_{cri} = \frac{1}{4} \pi D^2 (2gD \triangle \rho / \rho_0 )0.1754 exp (0.5536ε) $$<center>
#
#   When the pressure difference across the ceiling vent $\triangle P_{0} ≥ \triangle P_{cri}$, there will be a unidirectional flow, and the flow rate can be expressed by
#   <center>$$ \dot V = \big\{ 1−C_2^2 +[C_2^42 +C_1^2 (\triangle P_o /\triangle P_{cri} −1)]^\frac{1}{2} \big\} \dot{ V_{cri} } $$ <center>
#
#   where $c_1 ≈ 3.37$ and $c_2 ≈ 1.045$.
#
#   When $0 ≤ \triangle P_{0} ≤ \triangle P_{cri}$, there will be a bidirectional flow, the net volume flowrate across the ceiling vent can be calculated by
#   <center>$$ \dot{V_{net}} = \dot{V_{cri}} \{ M −[1+(M^2 −1)(1−\triangle P_o /\triangle P_{cri}  ]^ \frac{1}{2} \}/(M-1)$$<center>
#
#   where $M = 9.1$.
#
#   The volume flow rate into the compartment can be expressed as
#   <center>$$ \dot V_{u->l} = [(1+ \frac{m_3}{2})(1− \triangle P_o /\triangle P_{cri} )^2 -(2+\frac{m_3}{2})(1− \triangle P_o / \triangle P_{cri})]^2 \dot V_{ex.max} $$<center>
#
#   where $m_3$ is 0.7070 and $\dot V_{ex,max}$ is the maximum volume
# exchange rate while $\triangle P_o =0$. Epstein have measured the transfer of fluid from the lower to the upper chambers using water below and a brine above (density ratio 1.1 or less). They found that, at zero net volume flow (the lower chamber was closed except for a ceiling hole 2 in. in diameter or less), the fluid transfer to the upper chamber was
# <center>$$ \dot V_{ex,max} = 0.055 [D^5 g (\triangle \rho / \overline \rho )]^{1/2}$$<center>
#
#
#   At fire conditions, the $ε = -\triangle \rho / \overline \rho =−2(T_g −T_0)/(T_g +T_0)$

# %% [markdown]
# ###case in our condition
#   In our 2D ceiling vented compartment condition, if we apply the cooper's theory as follows.
#   $T_0 = 25 ^oC $
#   $ \triangle \rho = \rho_0 - \rho_g = \rho_0（\frac{T_g-T_0}{T_g}）$
#   $A=0.2*0.4$, $D= \sqrt{\frac{4A}{\pi}}=0.319m$

# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
sqrt(0.2*0.4*4/np.pi)
# Out:
# 0.3191538243211462

# %% [markdown]
#   We can get the critical pressure and critical flow rate as the function of Gas temperature as:
#   <center>$$\triangle P_{cri} = 0.2427(1+\frac{1}{2}ε) exp(1.1072ε) (4g \triangle ρ D)$$<center>
#   <center>$$\dot V_{cri} = \frac{1}{4} \pi D^2 (2gD \triangle \rho / \rho_0 )0.1754 exp (0.5536ε) $$<center>

# %%
T0=25.
Tg=np.linspace(25, 1000, 500)
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
    
figure(figsize=(12,4))

subplot(1,2,1)
plot(Tg,Pcri,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ P_{cri} / Pa$')
title('Critical Pressure $P_{cri}$')
grid()

subplot(1,2,2)
plot(Tg,Vcri,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ V_{cri} / m^3 / s$')
title('Critical Flow Rate')
grid()

# %% [markdown]
# From the experiment, we know the fire can burn for a relative long time. Fresh air should have flew in the compartment throught the vent. There will be a bidirectional flow, and $0 ≤ \triangle P_{0} ≤ \triangle P_{cri}$.Thus:
#   <center>$$ \dot V_{net} = \dot V_{cri} \{ M −[1+(M^2 −1)(1−\triangle P_o /\triangle P_{cri}  )]^ \frac{1}{2} \}/(M-1)$$<center>

# %%
from IPython.html.widgets import interact
T0=25.
Tg=np.linspace(25, 1000, 500)
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
def plot_Vnet(P0_to_Pcri):
    M=9.1
    Vnet=Vcri*(M-(1.+(M**2-1.)*(1.-P0_to_Pcri))**0.5)/(M-1.)
    plot(Tg,Vnet,'r-', label='Vnet')
    plot(Tg,Vcri,'k-', label='Vcri')

    xlabel('$T_g / ^oC$')
    ylabel('$ V_{net} / m^3 / s$')
    title('Net Flow Rate')
    legend(loc='lower right')
    grid()
    
interact(plot_Vnet, P0_to_Pcri=(0, 1, 0.1));

# %% [markdown]
# So the net flow rate should be smaller than the critical flow rate.
# Then we can calculate the vent inflow and vent out flow:
#
# <center>$$ \dot V_{u->l} = [(1+ \frac{m_3}{2})(1− \triangle P_o /\triangle P_{cri} )^2 -(2+\frac{m_3}{2})(1− \triangle P_o / \triangle P_{cri})]^2 \dot V_{ex.max} $$<center>
# <center>$$ \dot V_{ex,max} = 0.055 [D^5 g (\triangle \rho / \overline \rho )]^{1/2}$$<center>
#
# Where m3=0.7070

# %%
from IPython.html.widgets import interact
T0=25.
Tg=np.linspace(25, 1000, 500)
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Vmax=0.055*sqrt(D**5.*9.8*(-e))
m3=0.7070

def plot_Vin(P0_to_Pcri):
    Vin=Vmax*((1.+m3/2.)*(1.-P0_to_Pcri)**2-(2.+m3/2.)*(1.-P0_to_Pcri))**2
    plot(Tg,Vin,'r-', label='Vin')
    plot(Tg,Vmax,'k-', label='Vmax')

    xlabel('$T_g / ^oC$')
    ylabel('$ V_{in} / m^3 / s$')
    title('in Flow Rate')
    legend(loc='lower right')
    grid()
    
interact(plot_Vin, P0_to_Pcri=(0, 1, 0.1));

# %% [markdown]
# We can plot all this figures together:

# %%
from IPython.html.widgets import interact
T0=25.
Tg=np.linspace(25, 1000, 500)
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
Vmax=0.055*sqrt(D**5.*9.8*(-e))
m3=0.7070

def plot_V(P0_to_Pcri):
    M=9.1
    Vnet=Vcri*(M-(1.+(M**2-1.)*(1.-P0_to_Pcri))**0.5)/(M-1.)
    Vin=Vmax*((1.+m3/2.)*(1.-P0_to_Pcri)**2-(2.+m3/2.)*(1.-P0_to_Pcri))**2
    plot(Tg,Vnet+Vin,'b-', label='Vout')
    plot(Tg,Vin,'r-', label='Vin')

    xlabel('$T_g / ^oC$')
    ylabel('$ V_{in \, or \, out} / m^3 / s$')
    title('in/out Flow Rate')
    legend(loc='lower right')
    grid()
    
interact(plot_V, P0_to_Pcri=(0, 1, 0.1));

# %%
from IPython.html.widgets import interact
T0=25.
Tg=np.linspace(25, 1000, 500)
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
Vmax=0.055*sqrt(D**5.*9.8*(-e))
m3=0.7070

def plot_V(P0_to_Pcri):
    M=9.1
    Vnet=Vcri*(M-(1.+(M**2-1.)*(1.-P0_to_Pcri))**0.5)/(M-1.)
    Vin=Vmax*((1.+m3/2.)*(1.-P0_to_Pcri)**2-(2.+m3/2.)*(1.-P0_to_Pcri))**2
    plot(Tg,Vnet/Vin,'b-', label='Vout')

    xlabel('$T_g / ^oC$')
    ylabel('$ V_{in \, or \, out} / m^3 / s$')
    title('in/out Flow Rate')
    legend(loc='lower right')
    grid()
    
interact(plot_V, P0_to_Pcri=(0, 1, 0.1));

# %% [markdown]
# On the other aspect, the inflow and outflow should obey the mass conservation equation:
# <center>$$\dot m_{in}+\dot m_{f}=\dot m_{out}$$<center>
#
# We know the fuel flow rate $\dot m_f$
# At case of fuel flow rate of 15SLPM, $\dot m_f=4.575* 10^{-4} kg/s$. While at steady state, the smallest in flow air should still supply the combustion. The stoichiometric value is found from:
# $$C_3H_8 + 5(O_2+3.76N_2)  \to 3 CO_2+ 4 H_2O + 18.8 N_2$$
#
# The mass ratio of inflow air/fuel=686.4/44, so $\dot m_f$ is much smaller than $\dot m_{in}$, so we get $\dot m_{in} \approx \dot m_{out}$.
#
# Thus, we should have:
# <center>$$\frac{\dot V_{net}}{\dot V_{in}}=\frac{\dot V_{out} -\dot V_{in} }{\dot V_{in}}=\frac{T_g-T_0}{T_0}\, or \, \frac{\dot V_{out} }{\dot V_{in}}=\frac{T_g}{T_0}$$ <center>
#
# And from the simulation, we take $T_g$as the average compartment temperature. We get $T_g=280^oC \, or\,  553K$

# %%
#import data from matlab file
import scipy.io as sio
import pandas as pd
mat1 = sio.loadmat('/home/qize/Documents/MATLAB/T_O/Temp.mat')
Temp=pd.DataFrame(mat1['TT'])

#plot contour
x = np.linspace(-0.4, 0.4, 81)
y = np.linspace(0, 0.6, 61)
X, Y = np.meshgrid(x, y)
fig = figure(figsize=(8,4.5))
contourf(X, Y, Temp, 12, alpha=.75, cmap='jet')
colorbar()
CS=contour(X, Y, Temp, 12, colors='black', linewidth=.5)
manual_locations = [(-0.3, 0.1), (-0.3, 0.4), (-0.2, 0.5) , (0,0.5), (0.2, 0.5), (0.2, 0.35), \
                    (0.2, 0.3), (0.2, 0.2), ]
clabel(CS, inline=1, fontsize=10, manual=manual_locations)
title('Temperature',size=24)

# %%
mean(mean(Temp))
# Out:
# 280.05300274036284

# %% [markdown]
# Then, we can solve $\triangle P_o /\triangle P_{cri}$ from all the equations above

# %%
# %pylab inline

T0=25.
Tg=280
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
Vmax=0.055*sqrt(D**5.*9.8*(-e))
m3=0.7070
M=9.1

for P0_to_Pcri in np.linspace(0,0.8,81):
    Vnet=Vcri*(M-(1.+(M**2-1.)*(1.-P0_to_Pcri))**0.5)/(M-1.)
    Vin=Vmax*((1.+m3/2.)*(1.-P0_to_Pcri)**2-(2.+m3/2.)*(1.-P0_to_Pcri))**2
    if 0<(Vnet+Vin)/Vin-(Tg+273)/(T0+273)<0.3:
        print  P0_to_Pcri, (Vnet+Vin), Vin
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0.58 0.0134277264268 0.00719245615398
# 0.59 0.013330448327 0.00695837119342
# 0.6 0.013233650051 0.00672313615806
# 0.61 0.0131376525685 0.00648701233587
# 0.62 0.0130427862088 0.006250266641
# 0.63 0.0129493909969 0.00601317161381
# WARNING: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# So we finally get:
# $$\triangle P_o /\triangle P_{cri}=0.58$$
# $$\dot V_{out}=0.0134$$
# $$\dot V_{in}=0.0072$$
#
# From simulation, we also get the real gas inflow and out flow is as follows:

# %%
#read vent flow rate and oxygen fraction
DEVC = pd.read_csv('/home/qize/FDS_simulation/Copy_sever/fire_power/2700/2D_CVC_devc.csv', header=1)

figure(figsize=(12,8))

subplot(2,2,1)
plot(DEVC.Time, DEVC.FLOW_In_v, 'b-', linewidth=1, label="VOLUME FLOW IN")
plot(DEVC.Time, DEVC.FLOW_Out_v, 'r-', linewidth=1, label="VOLIME FLOW OUT")
legend(loc='upper right')
xlabel('Time / s')
ylabel('$\dot V_{IN} \,or\, \dot V_{OUT} \,/ \,m^3/s$')
xlim(0,600)
#ylim(0.13,0.21)

subplot(2,2,2)
plot(DEVC.Time, DEVC.FLOW_Out_v-DEVC.FLOW_In_v, 'k-', linewidth=1, label="NET FLOW RATE")
legend(loc='upper right')
xlabel('Time / s')
ylabel('$\dot V_{NET} \,/ \,m^3/s$')
xlim(0,600)
#ylim(0,1000)

subplot(2,2,3)
plot(DEVC.Time, DEVC.FLOW_In, 'b-', linewidth=1, label="MASS FLOW IN")
plot(DEVC.Time, DEVC.FLOW_Out, 'r-', linewidth=1, label="MASS FLOW OUT")
legend(loc='upper right')
xlabel('Time / s')
ylabel('$\dot m_{IN} \,or\, \dot m_{OUT} \,/ \,kg/s$')
xlim(0,600)
#ylim(0.13,0.21)

subplot(2,2,4)
plot(DEVC.Time, DEVC.FLOW_Out-DEVC.FLOW_In, 'k-', linewidth=1, label="NET FLOW RATE")
legend(loc='upper right')
xlabel('Time / s')
ylabel('$\dot m_{NET} \,/ \,kg/s$')
xlim(0,600)
#ylim(0.13,0.21)
# Out:
# (0, 600)

# %%
mean(DEVC.FLOW_Out_v)/mean(DEVC.FLOW_In_v)*298
# Out:
# 816.09065577988281

# %%
mean(DEVC.FLOW_In_v), mean(DEVC.FLOW_Out_v)
# Out:
# (0.0075491499652942211, 0.020673794448851143)

# %% [markdown]
# Since the compartment is totally closed except the only ceiling vent,  the inflow and outflow should obey the mass conservation equation:
# <center>$$\dot m_{in}+\dot m_{f}=\dot m_{out}$$<center>
#
# we know the fuel flow rate $\dot m_f$
# At case of fuel flow rate of 15SLPM, $\dot m_f=4.575* 10^{-4} kg/s$. while at steady state, the smallest in flow air should still supply the combustion. The stoichiometric value is found from:
# $$C_3H_8 + 5(O_2+3.76N_2)  \to 3 CO_2+ 4 H_2O + 18.8 N_2$$
#
# The mass ratio of inflow air/fuel=686.4/44, so $\dot m_f$ is much smaller than $\dot m_{in}$, so we get $\dot m_{in} \approx \dot m_{out}$.
#
# But $T_g$ may be two times $T_0$, so $\dot V_{out}$ is much larger than  $\dot V_{out}$. The $\dot V_{net}$ can not be zero. That means there should be a small $\triangle P_{0}$ produced by the expand of gas heated by the fire.
#
# According to "Enclosure fire dynamics" or WK Chow's derivation, for a compartment with an opening of area $A$ and discharge coefficient $C_d$, the pressure variations resulted from a fire with efficient gas heating rate $Q_o$, which is total heat release mines heat loss, to give hot gas of temperature Tg and density $\rho_g$, expansion giving a pressure difference $\triangle P_p$:
# $$\triangle P_p=\frac{1}{2\rho_g}(\frac{Q_g}{C_pT_gAC_d})^2$$
#
# In our condition the pressure would drive $\dot m_{in}$ inflow and $\dot m_{out}$ outflow, so the pressure difference $\triangle P_p$ should be:
#
# $$\triangle P_p=\frac{1}{2\rho_g}(\frac{Q_g}{C_p(T_g-T_0)AC_d})^2$$
#
# for shoallow rectangle hole, $C_d=0.7$, from simulation we know the total heat release rate and heat loss rate.

# %%
#read heat release rate
import pandas as pd
# %pylab inline
HRR = pd.read_csv('/home/qize/FDS_simulation/Copy_sever/fire_power/2700/2D_CVC_hrr.csv', header=1)
figure(figsize=(6,4))
plot(HRR.Time,HRR.HRR,'k-', label='HRR')
plot(HRR.Time,-HRR.Q_RADI,'b-', label='Q_RADI')
plot(HRR.Time,-HRR.Q_CONV,'r-', label='Q_CONV')
plot(HRR.Time,-HRR.Q_COND,'g-', label='Q_COND')
xlabel('$Time / s$')
ylabel('$ Heat rate / kw $')
title('Heat balance')
xlim(0,600)
legend(loc='upper right')

# %%
mean(-HRR.Q_CONV)

# %% [markdown]
# Take $Q_g=5.38kw$, and we can calculate the $\triangle P_p$

# %%
T0=25.
Tg=np.linspace(25, 1000, 500)
DP=Tg/(2*1.21*(T0+273))*(5380/(1000*(Tg-T0)*0.08*0.7))**2
figure(figsize=(6,4))
plot(Tg,DP,'k-')
xlim(100,500)
ylim(0,5)

# %%
mean(DEVC.FLOW_Out-DEVC.FLOW_In)

# %%
T0=25.
Tg=np.linspace(25, 1000, 500)
mf=0.0004575
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2.*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
Vnet=2.*(mf/44*1000)*22.4/1000*(Tg+273)/(T0+273)
Vdiff=Vnet/Vcri
M=9.1
Pdiff=1.-(((M-Vdiff*(M-1.))**2-1.)/(M**2-1.))
P0=Pcri*Pdiff
Vmax=0.055*sqrt(D**5.*9.8*(-e))
m3=0.7070
Vin=Vmax*((1+m3/2.)*(1.-Pdiff)**2-(2.+m3/2.)*(1.-Pdiff))**2

figure(figsize=(12,4))

subplot(1,2,1)
plot(Tg,Vmax,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ \dot V_{ex.max} / m^3/s$')
title('Max Reference Flow Rate')

subplot(1,2,2)
plot(Tg,Vin,'b-')
plot(Tg,Vin+Vnet,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ \dot V_{IN} \,or\, \dot V_{OUT} \,/ \,m^3/s$')
title('Predicted In and Out flow Rate')

# %%
T0=25.
Tg=np.linspace(25, 1000, 500)
mf=0.0004575
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)


Vdiff=Vnet/Vcri
M=9.1
Pdiff=1-(((M-Vdiff*(M-1))**2-1)/(M**2-1))
P0=Pcri*Pdiff
    
figure(figsize=(12,4))

subplot(1,2,1)
plot(Tg,Vnet,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ V_{net} / Pa$')
title('Net Flow Rate')

subplot(1,2,2)
plot(Tg,P0,'r-')
xlabel('$T_g / ^oC$')
ylabel('$ P_0 / P_a$')
title('P0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-210dac35ec27> in <module>()
#      16
#      17 subplot(1,2,1)
# ---> 18 plot(Tg,Vnet,'r-')
#      19 xlabel('$T_g / ^oC$')
#      20 ylabel('$ V_{net} / Pa$')
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
# ...

# %%
from sympy import Eq, Symbol, solve

T0=25.
Tg=400
mf=0.0004575
e=2.*(T0-Tg)/(T0+Tg)
D=0.319
M=9.1
m3=0.7070
Pcri=0.2427*(1.+0.5*e)*exp(1.1072*e)*(4*9.8*D*1.21*(Tg-T0)/(Tg+273))
Vcri=1.0/4.0*np.pi*D**2*(2*9.8*D*(Tg-T0)/(Tg+273))*0.1754*exp(0.5536*e)
Vmax=0.055*sqrt(D**5.*9.8*(-e))

Pd = Symbol('Pd')
Vnet=Vcri*(M-(1.+(M**2-1.)*(1.-Pd))**0.5)/(M-1)
Vin=Vmax*((1.+m3/2.)*(1.-Pd)**2-(2.+m3/2.)*(1.-Pd))**2
eqn = Eq((Vcri*(M-(1.+(M**2-1.)*(1.-Pd))**0.5)/(M-1))/(Vmax*((1.+m3/2.)*(1.-Pd)**2-(2.+m3/2.)*(1.-Pd))**2), (Tg-T0)/(T0+273))

print solve(eqn)

# %% [markdown]
# Then we can calculate the $\dot V_{ex,max}$ and $\dot V_{u->l}$
# as:
# <center>$$ \dot V_{ex,max} = 0.055 [D^5 g (\triangle \rho / \overline \rho )]^{1/2}$$<center>
# <center>$$ \dot V_{u->l} = [(1+ \frac{m_3}{2})(1− \triangle P_o /\triangle P_{cri} )^2 -(2+\frac{m_3}{2})(1− \triangle P_o / \triangle P_{cri})]^2 \dot V_{ex.max} $$<center>

# %% [markdown]
# On the other aspect, the inflow and outflow should obey the mass conservation equation:
# <center>$$\dot m_{in}+\dot m_{f}=\dot m_{out}$$<center>
#
# we know the fuel flow rate $\dot m_f$
# At case of fuel flow rate of 15SLPM, $\dot m_f=4.575* 10^{-4} kg/s$, this is much smaller than $\dot m_{in}$, so we get $\dot m_{in} \approx \dot m_{out}$.
#
# Thus, we should have:
# <center>$$\frac{\dot V_{net}}{\dot V_{in}}=\frac{\dot V_{out} -\dot V_{in} }{\dot V_{in}}=\frac{T_g-T_0}{T_0}$$<center>
#
# Apply this equation into the relation above, we can solve the $\triangle P_o$
